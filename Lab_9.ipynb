# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshukumar12123/APSLAB/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def dijkstra(graph, start):
    distances = {}
    previous = {}
    visited = []


    for node in graph:
        distances[node] = float('inf')
        previous[node] = None

    distances[start] = 0


    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous[neighbor] = min_node

    return distances, previous



def get_path(previous, start, target):
    path = []
    current = target

    while current is not None:
        path.append(current)
        current = previous[current]

    path.reverse()

    if path[0] == start:
        return path
    return []




graph = {}

n = int(input("Enter number of nodes: "))

print("\nEnter nodes and their neighbors (format: A B 4 means A->B weight 4)")
print("Type 'done' to stop each node input.\n")

for _ in range(n):
    node = input("Enter node name: ")
    graph[node] = {}

    while True:
        data = input(f"Enter neighbor of {node} (or 'done'): ")

        if data.lower() == "done":
            break

        neighbor, weight = data.split()
        graph[node][neighbor] = int(weight)



print("\nNow add 2 extra nodes manually.")

for _ in range(2):
    node = input("Enter new node name: ")
    graph[node] = {}

    while True:
        data = input(f"Enter neighbor of {node} (or 'done'): ")

        if data.lower() == "done":
            break

        neighbor, weight = data.split()
        graph[node][neighbor] = int(weight)



while True:
    start = input("\nEnter source node (or 'exit'): ")

    if start.lower() == "exit":
        break

    if start not in graph:
        print("Invalid node!")
        continue

    distances, previous = dijkstra(graph, start)

    print("\nShortest distances and paths from", start)

    for node in graph:
        path = get_path(previous, start, node)

        print(f"\n{start} → {node}")
        print("Distance:", distances[node])
        print("Path:", " -> ".join(path))
# Out:
# Enter number of nodes: 5
#
# Enter nodes and their neighbors (format: A B 4 means A->B weight 4)
# Type 'done' to stop each node input.
#
# Enter node name: A
# Enter neighbor of A (or 'done'): B 1
# Enter neighbor of A (or 'done'): E 7
# Enter neighbor of A (or 'done'): done
# Enter node name: B
# Enter neighbor of B (or 'done'): C 5
# Enter neighbor of B (or 'done'): D 4
# Enter neighbor of B (or 'done'): E 3
# Enter neighbor of B (or 'done'): done
# Enter node name: c
# Enter neighbor of c (or 'done'): done
# Enter node name: D
# Enter neighbor of D (or 'done'): A 1
# Enter neighbor of D (or 'done'): C 2
# Enter neighbor of D (or 'done'): done
# Enter node name: E
# Enter neighbor of E  (or 'done'): D 8
# Enter neighbor of E  (or 'done'): done
#
# Now add 2 extra nodes manually.
# Enter new node name: F
# Enter neighbor of F (or 'done'): G 0
# Enter neighbor of F (or 'done'): done
# Enter new node name: G
# Enter neighbor of G (or 'done'): C 1
# Enter neighbor of G (or 'done'): D 1
# Enter neighbor of G (or 'done'): done
#
# Enter source node (or 'exit'): A
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_680/762226555.py in <cell line: 0>()
#     104         continue
#     105
# --> 106     distances, previous = dijkstra(graph, start)
#     107
#     108     print("\nShortest distances and paths from", start)
#
# /tmp/ipykernel_680/762226555.py in dijkstra(graph, start)
#      30             new_distance = distances[min_node] + weight
#      31
# ---> 32             if new_distance < distances[neighbor]:
#      33                 distances[neighbor] = new_distance
#      34                 previous[neighbor] = min_node
#
# KeyError: 'E'
